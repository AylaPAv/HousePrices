# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from math import sqrt

# %%
dfTrain = pd.read_csv('data/train.csv')

# %%
tNullRows = dfTrain.isnull().sum().sort_values(ascending = False)
percent = (dfTrain.isnull().sum() / len(dfTrain)).sort_values(ascending = False)
missing_data = pd.concat([tNullRows, percent], axis = 1, keys = ['Total','Percent'])
missing_data[missing_data['Total']>0]
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageYrBlt      81  0.055479
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtFinType2     38  0.026027
# BsmtExposure     38  0.026027
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685

# %%
dfTrain.dropna(axis=1, how='any', inplace=True)

# %%
dfTrain.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.00
# LowQualFinSF   1460.0       5.844521     48.623081      0.0       0.00
# GrLivArea      1460.0    1515.463699    525.480383    334.0    1129.50
# BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.00
# BsmtHalfBath   1460.0       0.057534      0.238753      0.0       0.00
# FullBath       1460.0       1.565068      0.550916      0.0       1.00
# HalfBath       1460.0       0.382877      0.502885      0.0       0.00
# BedroomAbvGr   1460.0       2.866438      0.815778      0.0       2.00
# KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.00
# TotRmsAbvGrd   1460.0       6.517808      1.625393      2.0       5.00
# Fireplaces     1460.0       0.613014      0.644666      0.0       0.00
# GarageCars     1460.0       1.767123      0.747315      0.0       1.00
# GarageArea     1460.0     472.980137    213.804841      0.0     334.50
# WoodDeckSF     1460.0      94.244521    125.338794      0.0       0.00
# OpenPorchSF    1460.0      46.660274     66.256028      0.0       0.00
# EnclosedPorch  1460.0      21.954110     61.119149      0.0       0.00
# 3SsnPorch      1460.0       3.409589     29.317331      0.0       0.00
# ScreenPorch    1460.0      15.060959     55.757415      0.0       0.00
# PoolArea       1460.0       2.758904     40.177307      0.0       0.00
# MiscVal        1460.0      43.489041    496.123024      0.0       0.00
# MoSold         1460.0       6.321918      2.703626      1.0       5.00
# YrSold         1460.0    2007.815753      1.328095   2006.0    2007.00
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  129975.00
#
#                     50%        75%       max
# Id                730.5    1095.25    1460.0
# MSSubClass         50.0      70.00     190.0
# LotArea          9478.5   11601.50  215245.0
# OverallQual         6.0       7.00      10.0
# OverallCond         5.0       6.00       9.0
# YearBuilt        1973.0    2000.00    2010.0
# YearRemodAdd     1994.0    2004.00    2010.0
# BsmtFinSF1        383.5     712.25    5644.0
# BsmtFinSF2          0.0       0.00    1474.0
# BsmtUnfSF         477.5     808.00    2336.0
# TotalBsmtSF       991.5    1298.25    6110.0
# 1stFlrSF         1087.0    1391.25    4692.0
# 2ndFlrSF            0.0     728.00    2065.0
# LowQualFinSF        0.0       0.00     572.0
# GrLivArea        1464.0    1776.75    5642.0
# BsmtFullBath        0.0       1.00       3.0
# BsmtHalfBath        0.0       0.00       2.0
# FullBath            2.0       2.00       3.0
# HalfBath            0.0       1.00       2.0
# BedroomAbvGr        3.0       3.00       8.0
# KitchenAbvGr        1.0       1.00       3.0
# TotRmsAbvGrd        6.0       7.00      14.0
# Fireplaces          1.0       1.00       3.0
# GarageCars          2.0       2.00       4.0
# GarageArea        480.0     576.00    1418.0
# WoodDeckSF          0.0     168.00     857.0
# OpenPorchSF        25.0      68.00     547.0
# EnclosedPorch       0.0       0.00     552.0
# 3SsnPorch           0.0       0.00     508.0
# ScreenPorch         0.0       0.00     480.0
# PoolArea            0.0       0.00     738.0
# MiscVal             0.0       0.00   15500.0
# MoSold              6.0       8.00      12.0
# YrSold           2008.0    2009.00    2010.0
# SalePrice      163000.0  214000.00  755000.0

# %% [markdown]
# <h3>Implementing LARS algorithm</h3>
#
# We will implement de LARS algoritm for predictin SalePrice
#
# <u>Replacing namedfields by numeric values</u>

# %%
ncols = len(dfTrain.columns)
nrows = len(dfTrain)

# %%
dfTrain[dfTrain['MSZoning'] == 'C']
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, ExterQual, ExterCond, Foundation, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, GarageCars, GarageArea, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 62 columns]

# %%
dfTrain.groupby(['MSZoning']).count()
# Out:
#             Id  MSSubClass  LotArea  Street  LotShape  LandContour  Utilities  \
# MSZoning
# C (all)     10          10       10      10        10           10         10
# FV          65          65       65      65        65           65         65
# RH          16          16       16      16        16           16         16
# RL        1151        1151     1151    1151      1151         1151       1151
# RM         218         218      218     218       218          218        218
#
#           LotConfig  LandSlope  Neighborhood  ...  EnclosedPorch  3SsnPorch  \
# MSZoning                                      ...
# C (all)          10         10            10  ...             10         10
# FV               65         65            65  ...             65         65
# RH               16         16            16  ...             16         16
# RL             1151       1151          1151  ...           1151       1151
# RM              218        218           218  ...            218        218
#
#           ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# MSZoning
# C (all)            10        10       10      10      10        10
# FV                 65        65       65      65      65        65
# RH                 16        16       16      16      16        16
# RL               1151      1151     1151    1151    1151      1151
# RM                218       218      218     218     218       218
#
#           SaleCondition  SalePrice
# MSZoning
# C (all)              10         10
# FV                   65         65
# RH                   16         16
# RL                 1151       1151
# RM                  218        218
#
# [5 rows x 61 columns]

# %%
dfT_zoning_FV = dfTrain[dfTrain['MSZoning'] == 'FV']
dfT_zoning_FV
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 47      48          20       FV    11096   Pave      Reg         Lvl
# 56      57         160       FV     2645   Pave      Reg         Lvl
# 87      88         160       FV     3951   Pave      Reg         Lvl
# 105    106          60       FV     9375   Pave      Reg         Lvl
# 115    116         160       FV     3230   Pave      Reg         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1364  1365         160       FV     3180   Pave      Reg         Lvl
# 1365  1366          60       FV     7500   Pave      Reg         Lvl
# 1374  1375          60       FV    10625   Pave      Reg         Lvl
# 1442  1443          60       FV    11003   Pave      Reg         Lvl
# 1454  1455          20       FV     7500   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 47      AllPub    Inside       Gtl  ...             0         0           0
# 56      AllPub    Inside       Gtl  ...             0         0           0
# 87      AllPub    Corner       Gtl  ...             0         0           0
# 105     AllPub    Inside       Gtl  ...             0         0           0
# 115     AllPub    Corner       Gtl  ...             0         0           0
# ...        ...       ...       ...  ...           ...       ...         ...
# 1364    AllPub    Inside       Gtl  ...             0         0           0
# 1365    AllPub    Inside       Gtl  ...             0         0           0
# 1374    AllPub    Inside       Gtl  ...             0         0           0
# 1442    AllPub    Inside       Gtl  ...             0         0           0
# 1454    AllPub    Inside       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 47          0       0       7    2007        WD         Normal    249700
# 56          0       0       8    2009        WD        Abnorml    172500
# 87          0       0       6    2009       New        Partial    164500
# 105         0       0       8    2008        WD         Normal    250000
# 115         0       0       6    2007        WD         Normal    176000
# ...       ...     ...     ...     ...       ...            ...       ...
# 1364        0       0       4    2006        WD        Abnorml    144152
# 1365        0       0       1    2010        WD         Normal    216000
# 1374        0       0       7    2008        WD         Normal    250000
# 1442        0       0       4    2009        WD         Normal    310000
# 1454        0       0      10    2009        WD         Normal    185000
#
# [65 rows x 62 columns]

# %%
dfTrain.dtypes
# Out:
# Id                int64
# MSSubClass        int64
# MSZoning         object
# LotArea           int64
# Street           object
#                   ...
# MoSold            int64
# YrSold            int64
# SaleType         object
# SaleCondition    object
# SalePrice         int64
# Length: 62, dtype: object

# %%
dfTrain.query('MSZoning == "FV"')
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 47      48          20       FV    11096   Pave      Reg         Lvl
# 56      57         160       FV     2645   Pave      Reg         Lvl
# 87      88         160       FV     3951   Pave      Reg         Lvl
# 105    106          60       FV     9375   Pave      Reg         Lvl
# 115    116         160       FV     3230   Pave      Reg         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1364  1365         160       FV     3180   Pave      Reg         Lvl
# 1365  1366          60       FV     7500   Pave      Reg         Lvl
# 1374  1375          60       FV    10625   Pave      Reg         Lvl
# 1442  1443          60       FV    11003   Pave      Reg         Lvl
# 1454  1455          20       FV     7500   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 47      AllPub    Inside       Gtl  ...             0         0           0
# 56      AllPub    Inside       Gtl  ...             0         0           0
# 87      AllPub    Corner       Gtl  ...             0         0           0
# 105     AllPub    Inside       Gtl  ...             0         0           0
# 115     AllPub    Corner       Gtl  ...             0         0           0
# ...        ...       ...       ...  ...           ...       ...         ...
# 1364    AllPub    Inside       Gtl  ...             0         0           0
# 1365    AllPub    Inside       Gtl  ...             0         0           0
# 1374    AllPub    Inside       Gtl  ...             0         0           0
# 1442    AllPub    Inside       Gtl  ...             0         0           0
# 1454    AllPub    Inside       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 47          0       0       7    2007        WD         Normal    249700
# 56          0       0       8    2009        WD        Abnorml    172500
# 87          0       0       6    2009       New        Partial    164500
# 105         0       0       8    2008        WD         Normal    250000
# 115         0       0       6    2007        WD         Normal    176000
# ...       ...     ...     ...     ...       ...            ...       ...
# 1364        0       0       4    2006        WD        Abnorml    144152
# 1365        0       0       1    2010        WD         Normal    216000
# 1374        0       0       7    2008        WD         Normal    250000
# 1442        0       0       4    2009        WD         Normal    310000
# 1454        0       0      10    2009        WD         Normal    185000
#
# [65 rows x 62 columns]

# %%
cols = dfTrain.select_dtypes(include='object').columns
#np.arange(len(cols))
for i in np.arange(len(cols)):
    #cols_list = dfTrain[cols[i]].groupby(by=cols[i]).count()
    cols_list = list(dfTrain[[cols[i]]].groupby(by=cols[i]).count().index)
    print(cols[i],':',cols_list)
# Out:
# MSZoning : ['C (all)', 'FV', 'RH', 'RL', 'RM']
# Street : ['Grvl', 'Pave']
# LotShape : ['IR1', 'IR2', 'IR3', 'Reg']
# LandContour : ['Bnk', 'HLS', 'Low', 'Lvl']
# Utilities : ['AllPub', 'NoSeWa']
# LotConfig : ['Corner', 'CulDSac', 'FR2', 'FR3', 'Inside']
# LandSlope : ['Gtl', 'Mod', 'Sev']
# Neighborhood : ['Blmngtn', 'Blueste', 'BrDale', 'BrkSide', 'ClearCr', 'CollgCr', 'Crawfor', 'Edwards', 'Gilbert', 'IDOTRR', 'MeadowV', 'Mitchel', 'NAmes', 'NPkVill', 'NWAmes', 'NoRidge', 'NridgHt', 'OldTown', 'SWISU', 'Sawyer', 'SawyerW', 'Somerst', 'StoneBr', 'Timber', 'Veenker']
# Condition1 : ['Artery', 'Feedr', 'Norm', 'PosA', 'PosN', 'RRAe', 'RRAn', 'RRNe', 'RRNn']
# Condition2 : ['Artery', 'Feedr', 'Norm', 'PosA', 'PosN', 'RRAe', 'RRAn', 'RRNn']
# BldgType : ['1Fam', '2fmCon', 'Duplex', 'Twnhs', 'TwnhsE']
# HouseStyle : ['1.5Fin', '1.5Unf', '1Story', '2.5Fin', '2.5Unf', '2Story', 'SFoyer', 'SLvl']
# RoofStyle : ['Flat', 'Gable', 'Gambrel', 'Hip', 'Mansard', 'Shed']
# RoofMatl : ['ClyTile', 'CompShg', 'Membran', 'Metal', 'Roll', 'Tar&Grv', 'WdShake', 'WdShngl']
# Exterior1st : ['AsbShng', 'AsphShn', 'BrkComm', 'BrkFace', 'CBlock', 'CemntBd', 'HdBoard', 'ImStucc', 'MetalSd', 'Plywood', 'Stone', 'Stucco', 'VinylSd', 'Wd Sdng', 'WdShing']
# Exterior2nd : ['AsbShng', 'AsphShn', 'Brk Cmn', 'BrkFace', 'CBlock', 'CmentBd', 'HdBoard', 'ImStucc', 'MetalSd', 'Other', 'Plywood', 'Stone', 'Stucco', 'VinylSd', 'Wd Sdng', 'Wd Shng']
# ExterQual : ['Ex', 'Fa', 'Gd', 'TA']
# ExterCond : ['Ex', 'Fa', 'Gd', 'Po', 'TA']
# Foundation : ['BrkTil', 'CBlock', 'PConc', 'Slab', 'Stone', 'Wood']
# Heating : ['Floor', 'GasA', 'GasW', 'Grav', 'OthW', 'Wall']
# HeatingQC : ['Ex', 'Fa', 'Gd', 'Po', 'TA']
# CentralAir : ['N', 'Y']
# KitchenQual : ['Ex', 'Fa', 'Gd', 'TA']
# Functional : ['Maj1', 'Maj2', 'Min1', 'Min2', 'Mod', 'Sev', 'Typ']
# PavedDrive : ['N', 'P', 'Y']
# SaleType : ['COD', 'CWD', 'Con', 'ConLD', 'ConLI', 'ConLw', 'New', 'Oth', 'WD']
# SaleCondition : ['Abnorml', 'AdjLand', 'Alloca', 'Family', 'Normal', 'Partial']

# %%
dfTrain.query("MSZoning == 'FV'").describe()
# Out:
#                 Id  MSSubClass       LotArea  OverallQual  OverallCond  \
# count    65.000000   65.000000     65.000000    65.000000    65.000000
# mean    707.030769   90.461538   6638.861538     7.200000     5.030769
# std     402.406199   55.689731   3155.973354     0.794512     0.174036
# min      48.000000   20.000000   2117.000000     6.000000     5.000000
# 25%     382.000000   60.000000   3316.000000     7.000000     5.000000
# 50%     687.000000   60.000000   7500.000000     7.000000     5.000000
# 75%     978.000000  160.000000   9000.000000     8.000000     5.000000
# max    1455.000000  160.000000  12552.000000    10.000000     6.000000
#
#          YearBuilt  YearRemodAdd   BsmtFinSF1  BsmtFinSF2    BsmtUnfSF  ...  \
# count    65.000000     65.000000    65.000000        65.0    65.000000  ...
# mean   2004.507692   2004.830769   327.892308         0.0   663.123077  ...
# std       3.405524      3.352095   374.056944         0.0   422.816764  ...
# min    1997.000000   1998.000000     0.000000         0.0    32.000000  ...
# 25%    2003.000000   2003.000000     0.000000         0.0   319.000000  ...
# 50%    2005.000000   2006.000000   222.000000         0.0   600.000000  ...
# 75%    2007.000000   2007.000000   578.000000         0.0   912.000000  ...
# max    2009.000000   2009.000000  1238.000000         0.0  1632.000000  ...
#
#        WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# count   65.000000    65.000000           65.0       65.0    65.000000
# mean    57.276923   103.476923            0.0        0.0     3.046154
# std     81.755449    73.715693            0.0        0.0    24.558877
# min      0.000000     0.000000            0.0        0.0     0.000000
# 25%      0.000000    46.000000            0.0        0.0     0.000000
# 50%      0.000000   102.000000            0.0        0.0     0.000000
# 75%    144.000000   146.000000            0.0        0.0     0.000000
# max    216.000000   364.000000            0.0        0.0   198.000000
#
#        PoolArea  MiscVal     MoSold       YrSold      SalePrice
# count      65.0     65.0  65.000000    65.000000      65.000000
# mean        0.0      0.0   6.276923  2007.846154  214014.061538
# std         0.0      0.0   2.775494     1.325599   52369.662067
# min         0.0      0.0   1.000000  2006.000000  144152.000000
# 25%         0.0      0.0   4.000000  2007.000000  174000.000000
# 50%         0.0      0.0   6.000000  2008.000000  205950.000000
# 75%         0.0      0.0   8.000000  2009.000000  250000.000000
# max         0.0      0.0  12.000000  2010.000000  370878.000000
#
# [8 rows x 35 columns]
